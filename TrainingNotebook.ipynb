# %%
# !pip install -q --upgrade numexpr bottleneck

# %%
# !pip install -q transformers

# %%
import torch
import transformers
# No sagemaker imports needed!

# Check if your 20GB GPU is being recognized by PyTorch
print(f"GPU available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
# Out:
# GPU available: True
# GPU Name: NVIDIA H100 80GB HBM3 MIG 1g.20gb

# %%
import torch
from transformers import (
    AutoModelForCausalLM, 
    AutoTokenizer, 
    Trainer, 
    TrainingArguments
)

# 1. Set the hyperparameter values from the instructor's code
training_args = TrainingArguments(
    output_dir="./model_output", # Replaces output_path
    num_train_epochs=2,          # Replaces 'epochs': 2
    per_device_train_batch_size=4, # Replaces 'train_batch_size': 4
    per_device_eval_batch_size=2,  # Replaces 'valid_batch_size': 2
    learning_rate=1e-05,         # Replaces 'learning_rate': 1e-05
    # Additional good defaults for local H100 training:
    fp16=True,                   # Uses half-precision to save memory
    logging_steps=10
)

# 2. Load the model and tokenizer (replace 'model_name' with your course's model)
# tokenizer = AutoTokenizer.from_pretrained("model_name")
# model = AutoModelForCausalLM.from_pretrained("model_name")

# 3. Initialize the Trainer (assuming you have loaded 'train_dataset' and 'eval_dataset')
# trainer = Trainer(
#     model=model,
#     args=training_args,
#     train_dataset=train_dataset,
#     eval_dataset=eval_dataset,
# )

# 4. Start the training directly on your GPU!
# trainer.train()
